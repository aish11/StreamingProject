# %%
import io
import requests
from PIL import Image
from torchvision import models, transforms
from torch.autograd import Variable

# %%
resnet101=models.resnet101(pretrained=True)

# %%
normalize = transforms.Normalize(
   mean=[0.485, 0.456, 0.406],
   std=[0.229, 0.224, 0.225]
)
preprocess = transforms.Compose([
   transforms.Resize(256),
   transforms.CenterCrop(224),
   transforms.ToTensor(),
   normalize
])

# %%
#response = requests.get('cat.jpg')
img_pil = Image.open('cat.jpg')
img_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x372 at 0x7F4636A190>

# %%
img_tensor = preprocess(img_pil)
img_tensor.unsqueeze_(0)
# Out:
# tensor([[[[ 1.8550,  1.8550,  1.8550,  ...,  1.9920,  1.9920,  1.9920],
#           [ 1.8722,  1.8722,  1.8722,  ...,  2.0092,  1.9920,  1.9920],
#           [ 1.8722,  1.8722,  1.8722,  ...,  2.0092,  1.9920,  1.9920],
#           ...,
#           [ 2.1462,  2.1462,  2.1462,  ...,  1.5125,  1.4098,  1.2385],
#           [ 2.1462,  2.1462,  2.1462,  ...,  1.5297,  1.4269,  1.2899],
#           [ 2.1462,  2.1462,  2.1462,  ...,  1.5982,  1.4440,  1.3242]],
#
#          [[ 2.1134,  2.1134,  2.1134,  ...,  2.2535,  2.2535,  2.2535],
#           [ 2.1310,  2.1310,  2.1310,  ...,  2.2710,  2.2535,  2.2535],
#           [ 2.1310,  2.1310,  2.1310,  ...,  2.2710,  2.2535,  2.2535],
#           ...,
#           [ 2.3410,  2.3410,  2.3410,  ...,  1.6933,  1.5707,  1.3782],
#           [ 2.3410,  2.3410,  2.3410,  ...,  1.7283,  1.6232,  1.4482],
#           [ 2.3410,  2.3410,  2.3410,  ...,  1.7983,  1.6408,  1.4832]],
#
#          [[ 2.4308,  2.4308,  2.4308,  ...,  2.5354,  2.5354,  2.5354],
#           [ 2.4483,  2.4483,  2.4483,  ...,  2.5529,  2.5354,  2.5354],
#           [ 2.4483,  2.4483,  2.4483,  ...,  2.5529,  2.5354,  2.5354],
#           ...,
#           [ 2.5877,  2.5877,  2.5877,  ...,  1.9080,  1.7860,  1.5594],
#           [ 2.5877,  2.5877,  2.5877,  ...,  1.9254,  1.8208,  1.6291],
#           [ 2.5877,  2.5877,  2.5877,  ...,  1.9951,  1.8383,  1.6640]]]])

# %%
img_variable = Variable(img_tensor)
fc_out = resnet101(img_variable)

# %%
labels = {int(key):value for (key, value)
          in requests.get('https://s3.amazonaws.com/outcome-blog/wp-content/uploads/2017/02/25192225/cat.jpg').json().items()}
